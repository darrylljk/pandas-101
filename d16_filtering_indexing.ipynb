# %% [markdown]
# ## 16. Filtering and Indexing

# %%
# load pandas
import pandas as pd
import numpy as np

url = 'https://github.com/mattharrison/datasets/raw/master/data/siena2018-pres.csv'
df = pd.read_csv(url, index_col=0)

def tweak_siena_pres(df):
    def int64_to_uint8(df_):
        cols = df_.select_dtypes('int64')
        return (df_
                .astype({col:'uint8' for col in cols}))
    
    return (df
            .rename(columns={'Seq.':'Seq'})
            .rename(columns={k:v.replace(' ', '_') for k,v in
                             {
                                 'BG':'Background',
                                 'PL': 'Party leadership', 
                                 'CAb': 'Communication Ability',
                                 'RC': 'Relations with Congress',
                                 'CAp': 'Court appointments',
                                 'HE': 'Handling of economy',
                                 'L': 'Luck',
                                 'AC': 'Ability to compromise',
                                 'WR': 'Willing to take risks',
                                 'EAp': 'Executive appointments',
                                 'OA': 'Overall ability',
                                 'Im': 'Imagination',
                                 'DA': 'Domestic accomplishments',
                                 'Int': 'Integrity',
                                 'EAb': 'Executive ability',
                                 'FPA': 'Foreign policy accomplishments',
                                 'LA': 'Leadership ability',
                                 'IQ': 'Intelligence',
                                 'AM': 'Avoid crucial mistakes',
                                 'EV': "Experts' view",
                                 'O': 'Overall'
                                }.items()})
                                .astype({'Party': 'category'})
                                .pipe(int64_to_uint8)
                                .assign(
                                    Average_rank = lambda df_ : (df_.select_dtypes('uint8')
                                                                 .sum(axis=1).rank(method='dense').astype('uint8')),
                                    Quartile = lambda df_: pd.qcut(df_.Average_rank, 4, labels='1st 2nd 3rd 4th'.split())
                                )
            )

pres = tweak_siena_pres(df)
pres.head()
# Out:
#   Seq          President                  Party  Bg  Imagination  Integrity  \
# 1   1  George Washington            Independent   7            7          1
# 2   2         John Adams             Federalist   3           13          4
# 3   3   Thomas Jefferson  Democratic-Republican   2            2         14
# 4   4      James Madison  Democratic-Republican   4            6          7
# 5   5       James Monroe  Democratic-Republican   9           14         11
#
#    Intelligence  Luck  Willing_to_take_risks  Ability_to_compromise  ...  \
# 1            10     1                      6                      2  ...
# 2             4    24                     14                     31  ...
# 3             1     8                      5                     14  ...
# 4             3    16                     15                      6  ...
# 5            18     6                     16                      7  ...
#
#    Court_appointments  Handling_of_economy  Executive_appointments  \
# 1                   1                    1                       1
# 2                   4                   13                      15
# 3                   7                   20                       4
# 4                   6                   14                       7
# 5                  11                    9                       9
#
#    Domestic_accomplishments  Foreign_policy_accomplishments  \
# 1                         2                               2
# 2                        19                              13
# 3                         6                               9
# 4                        11                              19
# 5                        10                               5
#
#    Avoid_crucial_mistakes  Experts'_view  Overall  Average_rank  Quartile
# 1                       1              2        1             1       1st
# 2                      16             10       14            13       2nd
# 3                       7              5        5             5       1st
# 4                      11              8        7             7       1st
# 5                       6              9        8             8       1st
#
# [5 rows x 26 columns]

# %%
# renaming an index
def name_to_initial(val):
    names = val.split()
    return ' '.join([f'{names[0][0]}.', *names[1:]])

# %%
(pres
 .set_index('President')
 .rename(name_to_initial))[:10]
# Out:
#                   Seq                  Party  Bg  Imagination  Integrity  \
# President
# G. Washington       1            Independent   7            7          1
# J. Adams            2             Federalist   3           13          4
# T. Jefferson        3  Democratic-Republican   2            2         14
# J. Madison          4  Democratic-Republican   4            6          7
# J. Monroe           5  Democratic-Republican   9           14         11
# J. Quincy Adams     6  Democratic-Republican   1            9          6
# A. Jackson          7             Democratic  37           15         29
# M. Van Buren        8             Democratic  23           22         27
# W. Henry Harrison   9                   Whig  22           38         28
# J. Tyler           10            Independent  34           33         35
#
#                    Intelligence  Luck  Willing_to_take_risks  \
# President
# G. Washington                10     1                      6
# J. Adams                      4    24                     14
# T. Jefferson                  1     8                      5
# J. Madison                    3    16                     15
# J. Monroe                    18     6                     16
# J. Quincy Adams               5    29                     19
# A. Jackson                   28     4                      4
# M. Van Buren                 25    34                     28
# W. Henry Harrison            37    44                     32
# J. Tyler                     34    22                     26
#
#                    Ability_to_compromise  Executive_ability  ...  \
# President                                                    ...
# G. Washington                          2                  2  ...
# J. Adams                              31                 21  ...
# T. Jefferson                          14                  6  ...
# J. Madison                             6                 13  ...
# J. Monroe                              7                 10  ...
# J. Quincy Adams                       24                 22  ...
# A. Jackson                            38                 11  ...
# M. Van Buren                          20                 28  ...
# W. Henry Harrison                     41                 38  ...
# J. Tyler                              37                 36  ...
#
#                    Court_appointments  Handling_of_economy  \
# President
# G. Washington                       1                    1
# J. Adams                            4                   13
# T. Jefferson                        7                   20
# J. Madison                          6                   14
# J. Monroe                          11                    9
# J. Quincy Adams                    15                   17
# A. Jackson                         30                   25
# M. Van Buren                       25                   31
# W. Henry Harrison                  42                   41
# J. Tyler                           38                   34
#
#                    Executive_appointments  Domestic_accomplishments  \
# President
# G. Washington                           1                         2
# J. Adams                               15                        19
# T. Jefferson                            4                         6
# J. Madison                              7                        11
# J. Monroe                               9                        10
# J. Quincy Adams                        18                        21
# A. Jackson                             25                        17
# M. Van Buren                           26                        29
# W. Henry Harrison                      40                        42
# J. Tyler                               36                        36
#
#                    Foreign_policy_accomplishments  Avoid_crucial_mistakes  \
# President
# G. Washington                                   2                       1
# J. Adams                                       13                      16
# T. Jefferson                                    9                       7
# J. Madison                                     19                      11
# J. Monroe                                       5                       6
# J. Quincy Adams                                15                      14
# A. Jackson                                     23                      20
# M. Van Buren                                   27                      24
# W. Henry Harrison                              44                      37
# J. Tyler                                       26                      32
#
#                    Experts'_view  Overall  Average_rank  Quartile
# President
# G. Washington                  2        1             1       1st
# J. Adams                      10       14            13       2nd
# T. Jefferson                   5        5             5       1st
# J. Madison                     8        7             7       1st
# J. Monroe                      9        8             8       1st
# J. Quincy Adams               18       18            18       2nd
# A. Jackson                    19       19            19       2nd
# M. Van Buren                  28       25            25       3rd
# W. Henry Harrison             39       39            38       4th
# J. Tyler                      36       37            37       4th
#
# [10 rows x 25 columns]

# %%
# reset index
pres.reset_index()[:10]
# Out:
#    index Seq               President                  Party  Bg  Imagination  \
# 0      1   1       George Washington            Independent   7            7
# 1      2   2              John Adams             Federalist   3           13
# 2      3   3        Thomas Jefferson  Democratic-Republican   2            2
# 3      4   4           James Madison  Democratic-Republican   4            6
# 4      5   5            James Monroe  Democratic-Republican   9           14
# 5      6   6       John Quincy Adams  Democratic-Republican   1            9
# 6      7   7          Andrew Jackson             Democratic  37           15
# 7      8   8        Martin Van Buren             Democratic  23           22
# 8      9   9  William Henry Harrison                   Whig  22           38
# 9     10  10              John Tyler            Independent  34           33
#
#    Integrity  Intelligence  Luck  Willing_to_take_risks  ...  \
# 0          1            10     1                      6  ...
# 1          4             4    24                     14  ...
# 2         14             1     8                      5  ...
# 3          7             3    16                     15  ...
# 4         11            18     6                     16  ...
# 5          6             5    29                     19  ...
# 6         29            28     4                      4  ...
# 7         27            25    34                     28  ...
# 8         28            37    44                     32  ...
# 9         35            34    22                     26  ...
#
#    Court_appointments  Handling_of_economy  Executive_appointments  \
# 0                   1                    1                       1
# 1                   4                   13                      15
# 2                   7                   20                       4
# 3                   6                   14                       7
# 4                  11                    9                       9
# 5                  15                   17                      18
# 6                  30                   25                      25
# 7                  25                   31                      26
# 8                  42                   41                      40
# 9                  38                   34                      36
#
#    Domestic_accomplishments  Foreign_policy_accomplishments  \
# 0                         2                               2
# 1                        19                              13
# 2                         6                               9
# 3                        11                              19
# 4                        10                               5
# 5                        21                              15
# 6                        17                              23
# 7                        29                              27
# 8                        42                              44
# 9                        36                              26
#
#    Avoid_crucial_mistakes  Experts'_view  Overall  Average_rank  Quartile
# 0                       1              2        1             1       1st
# 1                      16             10       14            13       2nd
# 2                       7              5        5             5       1st
# 3                      11              8        7             7       1st
# 4                       6              9        8             8       1st
# 5                      14             18       18            18       2nd
# 6                      20             19       19            19       2nd
# 7                      24             28       25            25       3rd
# 8                      37             39       39            38       4th
# 9                      32             36       37            37       4th
#
# [10 rows x 27 columns]

# %%
# index by position
pres.iloc[:10]
# Out:
#    Seq               President                  Party  Bg  Imagination  \
# 1    1       George Washington            Independent   7            7
# 2    2              John Adams             Federalist   3           13
# 3    3        Thomas Jefferson  Democratic-Republican   2            2
# 4    4           James Madison  Democratic-Republican   4            6
# 5    5            James Monroe  Democratic-Republican   9           14
# 6    6       John Quincy Adams  Democratic-Republican   1            9
# 7    7          Andrew Jackson             Democratic  37           15
# 8    8        Martin Van Buren             Democratic  23           22
# 9    9  William Henry Harrison                   Whig  22           38
# 10  10              John Tyler            Independent  34           33
#
#     Integrity  Intelligence  Luck  Willing_to_take_risks  \
# 1           1            10     1                      6
# 2           4             4    24                     14
# 3          14             1     8                      5
# 4           7             3    16                     15
# 5          11            18     6                     16
# 6           6             5    29                     19
# 7          29            28     4                      4
# 8          27            25    34                     28
# 9          28            37    44                     32
# 10         35            34    22                     26
#
#     Ability_to_compromise  ...  Court_appointments  Handling_of_economy  \
# 1                       2  ...                   1                    1
# 2                      31  ...                   4                   13
# 3                      14  ...                   7                   20
# 4                       6  ...                   6                   14
# 5                       7  ...                  11                    9
# 6                      24  ...                  15                   17
# 7                      38  ...                  30                   25
# 8                      20  ...                  25                   31
# 9                      41  ...                  42                   41
# 10                     37  ...                  38                   34
#
#     Executive_appointments  Domestic_accomplishments  \
# 1                        1                         2
# 2                       15                        19
# 3                        4                         6
# 4                        7                        11
# 5                        9                        10
# 6                       18                        21
# 7                       25                        17
# 8                       26                        29
# 9                       40                        42
# 10                      36                        36
#
#     Foreign_policy_accomplishments  Avoid_crucial_mistakes  Experts'_view  \
# 1                                2                       1              2
# 2                               13                      16             10
# 3                                9                       7              5
# 4                               19                      11              8
# 5                                5                       6              9
# 6                               15                      14             18
# 7                               23                      20             19
# 8                               27                      24             28
# 9                               44                      37             39
# 10                              26                      32             36
#
#     Overall  Average_rank  Quartile
# 1         1             1       1st
# 2        14            13       2nd
# 3         5             5       1st
# 4         7             7       1st
# 5         8             8       1st
# 6        18            18       2nd
# 7        19            19       2nd
# 8        25            25       3rd
# 9        39            38       4th
# 10       37            37       4th
#
# [10 rows x 26 columns]

# %%
pres.iloc[1]
# Out:
# Seq                                        2
# President                         John Adams
# Party                             Federalist
# Bg                                         3
# Imagination                               13
# Integrity                                  4
# Intelligence                               4
# Luck                                      24
# Willing_to_take_risks                     14
# Ability_to_compromise                     31
# Executive_ability                         21
# Leadership_ability                        21
# Communication_Ability                     13
# Overall_ability                            8
# Party_leadership                          28
# Relations_with_Congress                   17
# Court_appointments                         4
# Handling_of_economy                       13
# Executive_appointments                    15
# Domestic_accomplishments                  19
# Foreign_policy_accomplishments            13
# Avoid_crucial_mistakes                    16
# Experts'_view                             10
# Overall                                   14
# Average_rank                              13
# Quartile                                 2nd
# Name: 2, dtype: object

# %%
pres.iloc[[1]] # double brackets return dataframe
# Out:
#   Seq   President       Party  Bg  Imagination  Integrity  Intelligence  Luck  \
# 2   2  John Adams  Federalist   3           13          4             4    24
#
#    Willing_to_take_risks  Ability_to_compromise  ...  Court_appointments  \
# 2                     14                     31  ...                   4
#
#    Handling_of_economy  Executive_appointments  Domestic_accomplishments  \
# 2                   13                      15                        19
#
#    Foreign_policy_accomplishments  Avoid_crucial_mistakes  Experts'_view  \
# 2                              13                      16             10
#
#    Overall  Average_rank  Quartile
# 2       14            13       2nd
#
# [1 rows x 26 columns]

# %%
pres.loc[1:5]
# Out:
#   Seq          President                  Party  Bg  Imagination  Integrity  \
# 1   1  George Washington            Independent   7            7          1
# 2   2         John Adams             Federalist   3           13          4
# 3   3   Thomas Jefferson  Democratic-Republican   2            2         14
# 4   4      James Madison  Democratic-Republican   4            6          7
# 5   5       James Monroe  Democratic-Republican   9           14         11
#
#    Intelligence  Luck  Willing_to_take_risks  Ability_to_compromise  ...  \
# 1            10     1                      6                      2  ...
# 2             4    24                     14                     31  ...
# 3             1     8                      5                     14  ...
# 4             3    16                     15                      6  ...
# 5            18     6                     16                      7  ...
#
#    Court_appointments  Handling_of_economy  Executive_appointments  \
# 1                   1                    1                       1
# 2                   4                   13                      15
# 3                   7                   20                       4
# 4                   6                   14                       7
# 5                  11                    9                       9
#
#    Domestic_accomplishments  Foreign_policy_accomplishments  \
# 1                         2                               2
# 2                        19                              13
# 3                         6                               9
# 4                        11                              19
# 5                        10                               5
#
#    Avoid_crucial_mistakes  Experts'_view  Overall  Average_rank  Quartile
# 1                       1              2        1             1       1st
# 2                      16             10       14            13       2nd
# 3                       7              5        5             5       1st
# 4                      11              8        7             7       1st
# 5                       6              9        8             8       1st
#
# [5 rows x 26 columns]

# %%
# slice by using partial strings on sorted index, slice rows and columns
(pres
 .set_index('President')
 .sort_index()
 .loc['C': 'Thomas Jefferson', 'Party':'Integrity'])
# Out:
#                                        Party  Bg  Imagination  Integrity
# President
# Calvin Coolidge                   Republican  32           36         17
# Chester A. Arthur                 Republican  41           31         37
# Donald Trump                      Republican  43           40         44
# Dwight D. Eisenhower              Republican  11           18          5
# Franklin D. Roosevelt             Democratic   6            3         16
# Franklin Pierce                   Democratic  38           39         38
# George H. W. Bush                 Republican  10           27         18
# George W. Bush                    Republican  17           29         33
# George Washington                Independent   7            7          1
# Gerald Ford                       Republican  18           32         10
# Grover Cleveland                  Democratic  26           23         26
# Harry S. Truman                   Democratic  31           16          9
# Herbert Hoover                    Republican  13           35         15
# James A. Garfield                 Republican  22           25         21
# James Buchanan                    Democratic  36           43         40
# James K. Polk                     Democratic  19           10         23
# James Madison          Democratic-Republican   4            6          7
# James Monroe           Democratic-Republican   9           14         11
# Jimmy Carter                      Democratic  25           19          3
# John Adams                        Federalist   3           13          4
# John F. Kennedy                   Democratic  14            5         31
# John Quincy Adams      Democratic-Republican   1            9          6
# John Tyler                       Independent  34           33         35
# Lyndon B. Johnson                 Democratic  15           11         34
# Martin Van Buren                  Democratic  23           22         27
# Millard Fillmore                        Whig  40           37         36
# Richard Nixon                     Republican  16           21         43
# Ronald Reagan                     Republican  27           17         24
# Rutherford B. Hayes               Republican  35           30         32
# Theodore Roosevelt                Republican   5            4          8
# Thomas Jefferson       Democratic-Republican   2            2         14
